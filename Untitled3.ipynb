# %%
from scipy.integrate import RK45
import matplotlib.pyplot as plt
from SuPyModes.Geometry          import Geometry, Circle, Fused3
from SuPyModes.Solver            import SuPySolver
from SuPyModes.sellmeier         import Fused_silica
from SuPyModes.utils             import *


nClad = NA2nCore( 0.11, Fused_silica(1.3)  )
nCore = NA2nCore( 0.12, nClad )
FiberA = {'Core':(nCore, 4.6), 'Clad': (nClad,19.9/2)}


nClad = NA2nCore( 0.11, Fused_silica(1.3)  )
nCore = NA2nCore( 0.125, nClad )
FiberB = {'Core':(nCore, 4.5), 'Clad': (nClad, 33/2)}


nClad = NA2nCore( 0.2, Fused_silica(1.3)  )
nCore = NA2nCore( 0.14, nClad )
FiberC = {'Core':(nCore, 4.1), 'Clad': (nClad, 43.3/2)}



Clad00 = Circle( Position = [0,0], Radi = 140, Index = 1.433 )

Clad = Fused3(Radius =  62.5, Fusion  = 0.8, Index   = Fused_silica(1.55))

Clad0 = Circle( Position = Clad.C[0],
                Radi     = FiberA['Clad'][1],
                Index    = FiberA['Clad'][0] )

Clad1 = Circle( Position = Clad.C[1],
                Radi     = FiberB['Clad'][1],
                Index    = FiberB['Clad'][0] )

Clad2 = Circle( Position = Clad.C[2],
                Radi     = FiberC['Clad'][1],
                Index    = FiberC['Clad'][0] )

Core0 = Circle( Position = Clad.C[0],
                Radi     = FiberA['Core'][1],
                Index    = FiberA['Core'][0] )

Core1 = Circle( Position = Clad.C[1],
                Radi     = FiberA['Core'][1],
                Index    = FiberA['Core'][0] )

Core2 = Circle( Position = Clad.C[2],
                Radi     = FiberC['Core'][1],
                Index    = FiberC['Core'][0] )


Geo = Geometry(Objects = [Clad00, Clad, Clad0, Clad1, Clad2, Core0, Core1, Core2],
               Xbound  = [-150, 150],
               Ybound  = [-150, 150],
               Nx      = 150,
               Ny      = 150,
               debug   = 'INFO',
               Length  = None)
Geo.Plot()
# Out:
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 1586 	 Cost: 4723.2099037515145
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 2508 	 Cost: 4891.37102841493
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 1016 	 Cost: 4554.486126129103
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 664 	 Cost: 4379.045674202871
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 446 	 Cost: 4156.928177896317
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 311 	 Cost: 3831.5927331244766
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 228 	 Cost: 3337.7557747727087
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 177 	 Cost: 2570.740599580324
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 145 	 Cost: 1374.7843725035855
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 126 	 Cost: 511.16330014589585
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 113 	 Cost: 2995.9828883618684
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 133 	 Cost: 430.0324063114185
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 130 	 Cost: 153.43487304204973
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 37.186435073030225
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 128 	 Cost: 156.78700690209917
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 4.621383983283522
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 55.695416633307104
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 3.7523109031180866
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 1.9750312658188705
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.12858400362074462
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 1.8457413798987545
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.029403945398371434
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.7723686426879794
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.12409701626347669
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.0008688010493642651
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.0496525242970165
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.004912924064228719
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.005941769952187315
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.0002195955294155283
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.0034688205869315425
# INFO:SuPyModes.Geometry:Topology: concave 	 Rv: 129 	 Cost: 0.0008733766026125522
# INFO:SuPyModes.Geometry:Result Rv = 129.18239647328062

# %%
Sol = SuPySolver(Coupler=Geo)

SuperModes = Sol.GetModes(wavelength = 1.3,
                          Nstep      = 200,
                          Nsol       = 10,
                          ITRi       = 1,
                          ITRf       = 0.05,
                          tolerance  = 1e-20,
                          error      = 3,
                          Xsym       = 0,
                          Ysym       = 0 )
# Out:
# Computing super modes: [===================================] 100% Time: 0:05:30
# Sorting modes...[==========================================] 100% Time: 0:00:01

# %%
# %matplotlib notebook
SuperModes.Plot(Input=['Index','Fields','Adiabatic'], iter=[0, -1], nMax=8)
# Out:
# <img src="data:image/png;base64,..." width="800">
# INFO:root:Computing effective indices...
# <img src="data:image/png;base64,..." width="800">
# Computing adiabatic criterion... [=========================] 100% Time: 0:00:34
# <img src="data:image/png;base64,..." width="2700">
# <img src="data:image/png;base64,..." width="2700">

# %%
nClad = NA2nCore( 0.11, Fused_silica(1.3)  )
nCore = NA2nCore( 0.12, nClad )
FiberA = {'Core':(nCore, 4.6), 'Clad': (nClad,19.9/2)}
